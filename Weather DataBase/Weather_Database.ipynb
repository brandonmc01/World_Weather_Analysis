# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | grindavik
# Processing Record 2 of Set 1 | lompoc
# Processing Record 3 of Set 1 | amuntai
# Processing Record 4 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 1 | sao filipe
# Processing Record 6 of Set 1 | gazli
# Processing Record 7 of Set 1 | lahij
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | mar del plata
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | namibe
# Processing Record 12 of Set 1 | padang
# Processing Record 13 of Set 1 | lashio
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | dingle
# Processing Record 17 of Set 1 | eyl
# Processing Record 18 of Set 1 | aklavik
# Processing Record 19 of Set 1 | ksenyevka
# City not found. Skipping...
# Processing Record 20 of Set 1 | avarua
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | sorong
# Processing Record 23 of Set 1 | kodiak
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | ossora
# Processing Record 27 of Set 1 | port alfred
# Processing Record 28 of Set 1 | constitucion
# Processing Record 29 of Set 1 | deputatskiy
# Processing Record 30 of Set 1 | saskylakh
# Processing Record 31 of Set 1 | klaksvik
# Processing Record 32 of Set 1 | lofthus
# Processing Record 33 of Set 1 | caravelas
# Processing Record 34 of Set 1 | madimba
# Processing Record 35 of Set 1 | lagoa
# Processing Record 36 of Set 1 | hobart
# Processing Record 37 of Set 1 | yellowknife
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | aitape
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | vryburg
# Processing Record 42 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 1 | da lat
# Processing Record 44 of Set 1 | hithadhoo
# Processing Record 45 of Set 1 | esperance
# Processing Record 46 of Set 1 | hualmay
# Processing Record 47 of Set 1 | kapaa
# Processing Record 48 of Set 1 | shitanjing
# Processing Record 49 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 1 | sarkikaraagac
# Processing Record 1 of Set 2 | umarkot
# Processing Record 2 of Set 2 | qaanaaq
# Processing Record 3 of Set 2 | port elizabeth
# Processing Record 4 of Set 2 | barrow
# Processing Record 5 of Set 2 | saint-philippe
# Processing Record 6 of Set 2 | benguela
# Processing Record 7 of Set 2 | cuauhtemoc
# Processing Record 8 of Set 2 | thompson
# Processing Record 9 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 2 | nanortalik
# Processing Record 11 of Set 2 | port blair
# Processing Record 12 of Set 2 | te anau
# Processing Record 13 of Set 2 | mataura
# Processing Record 14 of Set 2 | ust-tsilma
# Processing Record 15 of Set 2 | coahuayana
# Processing Record 16 of Set 2 | suratgarh
# Processing Record 17 of Set 2 | omboue
# Processing Record 18 of Set 2 | ambilobe
# Processing Record 19 of Set 2 | barcarena
# Processing Record 20 of Set 2 | jamestown
# Processing Record 21 of Set 2 | madang
# Processing Record 22 of Set 2 | tiksi
# Processing Record 23 of Set 2 | puerto ayora
# Processing Record 24 of Set 2 | tasiilaq
# Processing Record 25 of Set 2 | salalah
# Processing Record 26 of Set 2 | norman wells
# Processing Record 27 of Set 2 | kiruna
# Processing Record 28 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 2 | severo-kurilsk
# Processing Record 30 of Set 2 | arraial do cabo
# Processing Record 31 of Set 2 | kaspiyskiy
# Processing Record 32 of Set 2 | yantarnyy
# Processing Record 33 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 34 of Set 2 | shingu
# Processing Record 35 of Set 2 | chuy
# Processing Record 36 of Set 2 | roald
# Processing Record 37 of Set 2 | victoria
# Processing Record 38 of Set 2 | aykhal
# Processing Record 39 of Set 2 | otradnoye
# Processing Record 40 of Set 2 | bambous virieux
# Processing Record 41 of Set 2 | kruisfontein
# Processing Record 42 of Set 2 | andenes
# Processing Record 43 of Set 2 | lethem
# Processing Record 44 of Set 2 | torbay
# Processing Record 45 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 2 | hasaki
# Processing Record 47 of Set 2 | carnarvon
# Processing Record 48 of Set 2 | san rafael
# Processing Record 49 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 2 | havre-saint-pierre
# Processing Record 1 of Set 3 | teya
# Processing Record 2 of Set 3 | conakry
# Processing Record 3 of Set 3 | manzanillo
# Processing Record 4 of Set 3 | atuona
# Processing Record 5 of Set 3 | quang ngai
# Processing Record 6 of Set 3 | simpang
# Processing Record 7 of Set 3 | georgetown
# Processing Record 8 of Set 3 | butaritari
# Processing Record 9 of Set 3 | castro
# Processing Record 10 of Set 3 | oranjemund
# Processing Record 11 of Set 3 | lyubech
# Processing Record 12 of Set 3 | waipawa
# Processing Record 13 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 3 | fort walton beach
# Processing Record 15 of Set 3 | ongandjera
# Processing Record 16 of Set 3 | schwedt
# Processing Record 17 of Set 3 | souillac
# Processing Record 18 of Set 3 | pevek
# Processing Record 19 of Set 3 | rocha
# Processing Record 20 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 3 | bredasdorp
# Processing Record 22 of Set 3 | bairiki
# Processing Record 23 of Set 3 | marystown
# Processing Record 24 of Set 3 | antofagasta
# Processing Record 25 of Set 3 | airai
# Processing Record 26 of Set 3 | chokurdakh
# Processing Record 27 of Set 3 | general pico
# Processing Record 28 of Set 3 | nikolskoye
# Processing Record 29 of Set 3 | sukumo
# Processing Record 30 of Set 3 | saint-joseph
# Processing Record 31 of Set 3 | axim
# Processing Record 32 of Set 3 | merrill
# Processing Record 33 of Set 3 | kendari
# Processing Record 34 of Set 3 | tchollire
# Processing Record 35 of Set 3 | mersing
# Processing Record 36 of Set 3 | chapais
# Processing Record 37 of Set 3 | mahebourg
# Processing Record 38 of Set 3 | taoudenni
# Processing Record 39 of Set 3 | simao
# Processing Record 40 of Set 3 | new norfolk
# Processing Record 41 of Set 3 | kotido
# Processing Record 42 of Set 3 | longonjo
# Processing Record 43 of Set 3 | broome
# Processing Record 44 of Set 3 | sibolga
# Processing Record 45 of Set 3 | luena
# Processing Record 46 of Set 3 | revda
# Processing Record 47 of Set 3 | cayenne
# Processing Record 48 of Set 3 | khatanga
# Processing Record 49 of Set 3 | porto novo
# Processing Record 50 of Set 3 | poum
# Processing Record 1 of Set 4 | alofi
# Processing Record 2 of Set 4 | beli potok
# Processing Record 3 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 4 | kaitangata
# Processing Record 5 of Set 4 | kerteh
# City not found. Skipping...
# Processing Record 6 of Set 4 | tadine
# Processing Record 7 of Set 4 | xihe
# Processing Record 8 of Set 4 | saravan
# Processing Record 9 of Set 4 | bethel
# Processing Record 10 of Set 4 | porosozero
# Processing Record 11 of Set 4 | zhuanghe
# Processing Record 12 of Set 4 | sur
# Processing Record 13 of Set 4 | asau
# Processing Record 14 of Set 4 | fort nelson
# Processing Record 15 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 16 of Set 4 | clyde river
# Processing Record 17 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 18 of Set 4 | mount isa
# Processing Record 19 of Set 4 | talnakh
# Processing Record 20 of Set 4 | gazojak
# Processing Record 21 of Set 4 | vaini
# Processing Record 22 of Set 4 | arkhangelos
# City not found. Skipping...
# Processing Record 23 of Set 4 | cabo san lucas
# Processing Record 24 of Set 4 | katherine
# Processing Record 25 of Set 4 | lluta
# Processing Record 26 of Set 4 | port hardy
# Processing Record 27 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 4 | kunyang
# Processing Record 29 of Set 4 | mantua
# Processing Record 30 of Set 4 | dikson
# Processing Record 31 of Set 4 | ribeira grande
# Processing Record 32 of Set 4 | egvekinot
# Processing Record 33 of Set 4 | sacramento
# Processing Record 34 of Set 4 | aksu
# Processing Record 35 of Set 4 | tura
# Processing Record 36 of Set 4 | nouadhibou
# Processing Record 37 of Set 4 | ilulissat
# Processing Record 38 of Set 4 | college
# Processing Record 39 of Set 4 | rosarito
# Processing Record 40 of Set 4 | roebourne
# Processing Record 41 of Set 4 | baykit
# Processing Record 42 of Set 4 | roswell
# Processing Record 43 of Set 4 | flinders
# Processing Record 44 of Set 4 | kalmunai
# Processing Record 45 of Set 4 | zaragoza
# Processing Record 46 of Set 4 | yerofey pavlovich
# Processing Record 47 of Set 4 | lavrentiya
# Processing Record 48 of Set 4 | luderitz
# Processing Record 49 of Set 4 | yenagoa
# Processing Record 50 of Set 4 | stanghelle
# Processing Record 1 of Set 5 | pauini
# Processing Record 2 of Set 5 | winslow
# Processing Record 3 of Set 5 | puerto leguizamo
# Processing Record 4 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 5 | campbellsville
# Processing Record 6 of Set 5 | laguna
# Processing Record 7 of Set 5 | tautira
# Processing Record 8 of Set 5 | yaan
# Processing Record 9 of Set 5 | lebu
# Processing Record 10 of Set 5 | bitung
# Processing Record 11 of Set 5 | provideniya
# Processing Record 12 of Set 5 | sinnamary
# Processing Record 13 of Set 5 | havoysund
# Processing Record 14 of Set 5 | pajarito
# Processing Record 15 of Set 5 | brae
# Processing Record 16 of Set 5 | alice springs
# Processing Record 17 of Set 5 | arman
# Processing Record 18 of Set 5 | los llanos de aridane
# Processing Record 19 of Set 5 | cadiz
# Processing Record 20 of Set 5 | itarema
# Processing Record 21 of Set 5 | husavik
# Processing Record 22 of Set 5 | solhan
# Processing Record 23 of Set 5 | najran
# Processing Record 24 of Set 5 | codrington
# Processing Record 25 of Set 5 | morro bay
# Processing Record 26 of Set 5 | miri
# Processing Record 27 of Set 5 | hamilton
# Processing Record 28 of Set 5 | chumikan
# Processing Record 29 of Set 5 | antsohihy
# Processing Record 30 of Set 5 | nainpur
# Processing Record 31 of Set 5 | pisco
# Processing Record 32 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 5 | okha
# Processing Record 34 of Set 5 | east london
# Processing Record 35 of Set 5 | kaduqli
# Processing Record 36 of Set 5 | teluk nibung
# Processing Record 37 of Set 5 | necochea
# Processing Record 38 of Set 5 | olga
# Processing Record 39 of Set 5 | mentok
# City not found. Skipping...
# Processing Record 40 of Set 5 | fuerte olimpo
# Processing Record 41 of Set 5 | joshimath
# Processing Record 42 of Set 5 | bichena
# Processing Record 43 of Set 5 | cashel
# Processing Record 44 of Set 5 | ibia
# Processing Record 45 of Set 5 | atasu
# Processing Record 46 of Set 5 | bathsheba
# Processing Record 47 of Set 5 | sri aman
# Processing Record 48 of Set 5 | ponta do sol
# Processing Record 49 of Set 5 | cartagena
# Processing Record 50 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 6 | northam
# Processing Record 2 of Set 6 | yumen
# Processing Record 3 of Set 6 | altay
# Processing Record 4 of Set 6 | sao felix do xingu
# Processing Record 5 of Set 6 | sitka
# Processing Record 6 of Set 6 | longyearbyen
# Processing Record 7 of Set 6 | faanui
# Processing Record 8 of Set 6 | baiyin
# Processing Record 9 of Set 6 | riyadh
# Processing Record 10 of Set 6 | morant bay
# Processing Record 11 of Set 6 | mehamn
# Processing Record 12 of Set 6 | dubenskiy
# City not found. Skipping...
# Processing Record 13 of Set 6 | beira
# Processing Record 14 of Set 6 | quatre cocos
# Processing Record 15 of Set 6 | bengkulu
# Processing Record 16 of Set 6 | sogdiondon
# City not found. Skipping...
# Processing Record 17 of Set 6 | buritis
# Processing Record 18 of Set 6 | callaway
# Processing Record 19 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 6 | tyup
# Processing Record 21 of Set 6 | port keats
# Processing Record 22 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 23 of Set 6 | progreso
# Processing Record 24 of Set 6 | abu kamal
# Processing Record 25 of Set 6 | ler
# Processing Record 26 of Set 6 | guerrero negro
# Processing Record 27 of Set 6 | houma
# Processing Record 28 of Set 6 | saint anthony
# Processing Record 29 of Set 6 | denpasar
# Processing Record 30 of Set 6 | srednekolymsk
# Processing Record 31 of Set 6 | hirara
# Processing Record 32 of Set 6 | vikramasingapuram
# Processing Record 33 of Set 6 | tuktoyaktuk
# Processing Record 34 of Set 6 | upernavik
# Processing Record 35 of Set 6 | constantine
# Processing Record 36 of Set 6 | san cristobal
# Processing Record 37 of Set 6 | akyab
# Processing Record 38 of Set 6 | floro
# Processing Record 39 of Set 6 | makokou
# Processing Record 40 of Set 6 | collierville
# Processing Record 41 of Set 6 | evensk
# Processing Record 42 of Set 6 | saldanha
# Processing Record 43 of Set 6 | dinsor
# City not found. Skipping...
# Processing Record 44 of Set 6 | tarauaca
# Processing Record 45 of Set 6 | sohag
# Processing Record 46 of Set 6 | kolokani
# Processing Record 47 of Set 6 | toamasina
# Processing Record 48 of Set 6 | tete
# Processing Record 49 of Set 6 | solvychegodsk
# Processing Record 50 of Set 6 | richard toll
# City not found. Skipping...
# Processing Record 1 of Set 7 | polunochnoye
# Processing Record 2 of Set 7 | ierapetra
# Processing Record 3 of Set 7 | vaitape
# Processing Record 4 of Set 7 | nanchang
# Processing Record 5 of Set 7 | magdiwang
# Processing Record 6 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 7 of Set 7 | muros
# Processing Record 8 of Set 7 | magdalena
# Processing Record 9 of Set 7 | inuvik
# Processing Record 10 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 11 of Set 7 | amarante do maranhao
# Processing Record 12 of Set 7 | yar-sale
# Processing Record 13 of Set 7 | tambul
# City not found. Skipping...
# Processing Record 14 of Set 7 | southbridge
# Processing Record 15 of Set 7 | jawhar
# Processing Record 16 of Set 7 | mahibadhoo
# Processing Record 17 of Set 7 | quepos
# Processing Record 18 of Set 7 | tuatapere
# Processing Record 19 of Set 7 | hay river
# Processing Record 20 of Set 7 | acarau
# Processing Record 21 of Set 7 | burhaniye
# Processing Record 22 of Set 7 | bengkalis
# City not found. Skipping...
# Processing Record 23 of Set 7 | tiarei
# Processing Record 24 of Set 7 | yeppoon
# Processing Record 25 of Set 7 | port lincoln
# Processing Record 26 of Set 7 | aksarka
# Processing Record 27 of Set 7 | amapa
# Processing Record 28 of Set 7 | zabaykalsk
# Processing Record 29 of Set 7 | dalvik
# Processing Record 30 of Set 7 | labuhan
# Processing Record 31 of Set 7 | poltava
# Processing Record 32 of Set 7 | mercedes
# Processing Record 33 of Set 7 | tual
# Processing Record 34 of Set 7 | roma
# Processing Record 35 of Set 7 | andros town
# Processing Record 36 of Set 7 | nantucket
# Processing Record 37 of Set 7 | ust-maya
# Processing Record 38 of Set 7 | russell
# Processing Record 39 of Set 7 | nisia floresta
# Processing Record 40 of Set 7 | komsomolskiy
# Processing Record 41 of Set 7 | palomares
# Processing Record 42 of Set 7 | sao borja
# Processing Record 43 of Set 7 | taloda
# Processing Record 44 of Set 7 | sawtell
# Processing Record 45 of Set 7 | jurado
# Processing Record 46 of Set 7 | datong
# Processing Record 47 of Set 7 | antalaha
# Processing Record 48 of Set 7 | ostrovnoy
# Processing Record 49 of Set 7 | aktash
# Processing Record 50 of Set 7 | boa vista
# Processing Record 1 of Set 8 | champerico
# Processing Record 2 of Set 8 | odesskoye
# Processing Record 3 of Set 8 | vila velha
# Processing Record 4 of Set 8 | yamethin
# Processing Record 5 of Set 8 | flin flon
# Processing Record 6 of Set 8 | karasburg
# Processing Record 7 of Set 8 | takanabe
# Processing Record 8 of Set 8 | campo verde
# Processing Record 9 of Set 8 | ucluelet
# Processing Record 10 of Set 8 | vanavara
# Processing Record 11 of Set 8 | price
# Processing Record 12 of Set 8 | alekseyevsk
# Processing Record 13 of Set 8 | takoradi
# Processing Record 14 of Set 8 | marovoay
# Processing Record 15 of Set 8 | fairbanks
# Processing Record 16 of Set 8 | kanelovskaya
# Processing Record 17 of Set 8 | sovetskiy
# Processing Record 18 of Set 8 | ewa beach
# Processing Record 19 of Set 8 | matay
# Processing Record 20 of Set 8 | pizarro
# Processing Record 21 of Set 8 | porto walter
# Processing Record 22 of Set 8 | verkhnyaya balkariya
# Processing Record 23 of Set 8 | shenjiamen
# Processing Record 24 of Set 8 | salon-de-provence
# Processing Record 25 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 8 | narasannapeta
# Processing Record 27 of Set 8 | kloulklubed
# Processing Record 28 of Set 8 | oruro
# Processing Record 29 of Set 8 | dimbokro
# Processing Record 30 of Set 8 | suzu
# City not found. Skipping...
# Processing Record 31 of Set 8 | hailar
# Processing Record 32 of Set 8 | verkhnyaya inta
# Processing Record 33 of Set 8 | zaliztsi
# Processing Record 34 of Set 8 | loiza
# Processing Record 35 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 8 | arkhangelskoye
# Processing Record 37 of Set 8 | punta alta
# Processing Record 38 of Set 8 | inirida
# Processing Record 39 of Set 8 | mopti
# Processing Record 40 of Set 8 | borogontsy
# Processing Record 41 of Set 8 | liepaja
# Processing Record 42 of Set 8 | burkhala
# City not found. Skipping...
# Processing Record 43 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 44 of Set 8 | sayyan
# Processing Record 45 of Set 8 | santo amaro da imperatriz
# Processing Record 46 of Set 8 | kemijarvi
# Processing Record 47 of Set 8 | nerchinsk
# Processing Record 48 of Set 8 | goundam
# Processing Record 49 of Set 8 | portland
# Processing Record 50 of Set 8 | quevedo
# Processing Record 1 of Set 9 | meulaboh
# Processing Record 2 of Set 9 | saint george
# Processing Record 3 of Set 9 | matucana
# Processing Record 4 of Set 9 | cavalcante
# Processing Record 5 of Set 9 | balogo
# Processing Record 6 of Set 9 | lively
# Processing Record 7 of Set 9 | bukachacha
# Processing Record 8 of Set 9 | bud
# Processing Record 9 of Set 9 | soyo
# Processing Record 10 of Set 9 | muisne
# Processing Record 11 of Set 9 | bongandanga
# Processing Record 12 of Set 9 | balikpapan
# Processing Record 13 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 9 | sambava
# Processing Record 15 of Set 9 | cubulco
# Processing Record 16 of Set 9 | zhanakorgan
# Processing Record 17 of Set 9 | gushikawa
# Processing Record 18 of Set 9 | erzin
# Processing Record 19 of Set 9 | ambovombe
# Processing Record 20 of Set 9 | takestan
# Processing Record 21 of Set 9 | hami
# Processing Record 22 of Set 9 | mbaiki
# Processing Record 23 of Set 9 | mandalgovi
# Processing Record 24 of Set 9 | kota
# Processing Record 25 of Set 9 | seoul
# Processing Record 26 of Set 9 | san patricio
# Processing Record 27 of Set 9 | asyut
# Processing Record 28 of Set 9 | saint pete beach
# Processing Record 29 of Set 9 | kavieng
# Processing Record 30 of Set 9 | katra
# Processing Record 31 of Set 9 | arkhangelsk
# Processing Record 32 of Set 9 | korla
# Processing Record 33 of Set 9 | kutum
# Processing Record 34 of Set 9 | bar harbor
# Processing Record 35 of Set 9 | gaurnadi
# Processing Record 36 of Set 9 | touros
# Processing Record 37 of Set 9 | dongsheng
# Processing Record 38 of Set 9 | popondetta
# Processing Record 39 of Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 40 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 9 | zhigansk
# Processing Record 42 of Set 9 | sept-iles
# Processing Record 43 of Set 9 | gull lake
# Processing Record 44 of Set 9 | macheng
# Processing Record 45 of Set 9 | iqaluit
# Processing Record 46 of Set 9 | lucapa
# Processing Record 47 of Set 9 | nelson bay
# Processing Record 48 of Set 9 | hastings
# Processing Record 49 of Set 9 | verkhnevilyuysk
# Processing Record 50 of Set 9 | noumea
# Processing Record 1 of Set 10 | chegdomyn
# Processing Record 2 of Set 10 | port moresby
# Processing Record 3 of Set 10 | sorland
# Processing Record 4 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 10 | port hedland
# Processing Record 6 of Set 10 | isla mujeres
# Processing Record 7 of Set 10 | makakilo city
# Processing Record 8 of Set 10 | itoman
# Processing Record 9 of Set 10 | mazamari
# Processing Record 10 of Set 10 | chardara
# Processing Record 11 of Set 10 | westport
# Processing Record 12 of Set 10 | okhotsk
# Processing Record 13 of Set 10 | mutare
# Processing Record 14 of Set 10 | lazaro cardenas
# Processing Record 15 of Set 10 | ati
# Processing Record 16 of Set 10 | manbij
# Processing Record 17 of Set 10 | juegang
# Processing Record 18 of Set 10 | laiagam
# City not found. Skipping...
# Processing Record 19 of Set 10 | grand-lahou
# Processing Record 20 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 21 of Set 10 | jalu
# Processing Record 22 of Set 10 | hudson bay
# Processing Record 23 of Set 10 | mackenzie
# Processing Record 24 of Set 10 | west point
# Processing Record 25 of Set 10 | mizpe ramon
# City not found. Skipping...
# Processing Record 26 of Set 10 | zyryanka
# Processing Record 27 of Set 10 | kedrovyy
# Processing Record 28 of Set 10 | bhuban
# Processing Record 29 of Set 10 | buala
# Processing Record 30 of Set 10 | nuuk
# Processing Record 31 of Set 10 | andra
# Processing Record 32 of Set 10 | florianopolis
# Processing Record 33 of Set 10 | antibes
# Processing Record 34 of Set 10 | cortez
# Processing Record 35 of Set 10 | srandakan
# Processing Record 36 of Set 10 | nome
# Processing Record 37 of Set 10 | vila franca do campo
# Processing Record 38 of Set 10 | qaqortoq
# Processing Record 39 of Set 10 | arona
# Processing Record 40 of Set 10 | lamu
# Processing Record 41 of Set 10 | porbandar
# Processing Record 42 of Set 10 | christchurch
# Processing Record 43 of Set 10 | hov
# Processing Record 44 of Set 10 | banyuwangi
# Processing Record 45 of Set 10 | honiara
# Processing Record 46 of Set 10 | abhar
# Processing Record 47 of Set 10 | ulaangom
# Processing Record 48 of Set 10 | huntly
# Processing Record 49 of Set 10 | yerbogachen
# Processing Record 50 of Set 10 | samana
# Processing Record 1 of Set 11 | aljezur
# Processing Record 2 of Set 11 | namie
# Processing Record 3 of Set 11 | tateyama
# Processing Record 4 of Set 11 | kamenka
# Processing Record 5 of Set 11 | ranong
# Processing Record 6 of Set 11 | marjamaa
# Processing Record 7 of Set 11 | bronnoysund
# Processing Record 8 of Set 11 | bambanglipuro
# Processing Record 9 of Set 11 | pastavy
# Processing Record 10 of Set 11 | severnyy
# Processing Record 11 of Set 11 | dipkarpaz
# City not found. Skipping...
# Processing Record 12 of Set 11 | wiang sa
# Processing Record 13 of Set 11 | surgut
# Processing Record 14 of Set 11 | cabedelo
# Processing Record 15 of Set 11 | athabasca
# Processing Record 16 of Set 11 | dhanera
# Processing Record 17 of Set 11 | khargone
# Processing Record 18 of Set 11 | brainerd
# Processing Record 19 of Set 11 | puruliya
# Processing Record 20 of Set 11 | huangmei
# Processing Record 21 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 22 of Set 11 | maku
# Processing Record 23 of Set 11 | honningsvag
# Processing Record 24 of Set 11 | sao joao da barra
# Processing Record 25 of Set 11 | hohhot
# Processing Record 26 of Set 11 | koundara
# Processing Record 27 of Set 11 | khrebtovaya
# Processing Record 28 of Set 11 | pazardzik
# City not found. Skipping...
# Processing Record 29 of Set 11 | banda aceh
# Processing Record 30 of Set 11 | mandera
# Processing Record 31 of Set 11 | todos santos
# Processing Record 32 of Set 11 | prado
# Processing Record 33 of Set 11 | losinyy
# Processing Record 34 of Set 11 | neiafu
# Processing Record 35 of Set 11 | tangier
# Processing Record 36 of Set 11 | cockburn town
# Processing Record 37 of Set 11 | leningradskiy
# Processing Record 38 of Set 11 | tari
# Processing Record 39 of Set 11 | jabiru
# City not found. Skipping...
# Processing Record 40 of Set 11 | yulara
# Processing Record 41 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 42 of Set 11 | byron bay
# Processing Record 43 of Set 11 | sakit
# Processing Record 44 of Set 11 | paamiut
# Processing Record 45 of Set 11 | tagusao
# Processing Record 46 of Set 11 | virginia beach
# Processing Record 47 of Set 11 | raymond terrace
# Processing Record 48 of Set 11 | sao miguel do araguaia
# Processing Record 49 of Set 11 | shache
# Processing Record 50 of Set 11 | zarubino
# Processing Record 1 of Set 12 | kita
# Processing Record 2 of Set 12 | gat
# Processing Record 3 of Set 12 | moroto
# Processing Record 4 of Set 12 | pandan
# Processing Record 5 of Set 12 | porto santo
# Processing Record 6 of Set 12 | vrangel
# Processing Record 7 of Set 12 | eldorado
# Processing Record 8 of Set 12 | sao domingos do maranhao
# Processing Record 9 of Set 12 | chimbote
# Processing Record 10 of Set 12 | geraldton
# Processing Record 11 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 12 of Set 12 | gama
# Processing Record 13 of Set 12 | katsuura
# Processing Record 14 of Set 12 | cururupu
# Processing Record 15 of Set 12 | palmer
# Processing Record 16 of Set 12 | micco
# Processing Record 17 of Set 12 | lilongwe
# Processing Record 18 of Set 12 | north bend
# Processing Record 19 of Set 12 | berdigestyakh
# Processing Record 20 of Set 12 | sidi qasim
# City not found. Skipping...
# Processing Record 21 of Set 12 | clarksdale
# Processing Record 22 of Set 12 | cherskiy
# Processing Record 23 of Set 12 | yeniseysk
# Processing Record 24 of Set 12 | kungurtug
# Processing Record 25 of Set 12 | wuchang
# Processing Record 26 of Set 12 | supe
# Processing Record 27 of Set 12 | chowchilla
# Processing Record 28 of Set 12 | temba
# Processing Record 29 of Set 12 | cidreira
# Processing Record 30 of Set 12 | vikindu
# Processing Record 31 of Set 12 | north marysville
# City not found. Skipping...
# Processing Record 32 of Set 12 | aflao
# Processing Record 33 of Set 12 | asfi
# Processing Record 34 of Set 12 | montepuez
# Processing Record 35 of Set 12 | waingapu
# Processing Record 36 of Set 12 | vernon
# Processing Record 37 of Set 12 | kolvereid
# Processing Record 38 of Set 12 | esso
# Processing Record 39 of Set 12 | brigantine
# Processing Record 40 of Set 12 | lazarev
# Processing Record 41 of Set 12 | the valley
# Processing Record 42 of Set 12 | balabac
# Processing Record 43 of Set 12 | zeya
# Processing Record 44 of Set 12 | shakhovskaya
# Processing Record 45 of Set 12 | durango
# Processing Record 46 of Set 12 | atar
# Processing Record 47 of Set 12 | jizan
# Processing Record 48 of Set 12 | fortuna
# Processing Record 49 of Set 12 | broken hill
# Processing Record 50 of Set 12 | beloha
# Processing Record 1 of Set 13 | nordborg
# Processing Record 2 of Set 13 | bilma
# Processing Record 3 of Set 13 | kajaani
# Processing Record 4 of Set 13 | rawson
# Processing Record 5 of Set 13 | delano
# Processing Record 6 of Set 13 | ambon
# Processing Record 7 of Set 13 | khash
# Processing Record 8 of Set 13 | huarmey
# Processing Record 9 of Set 13 | genhe
# Processing Record 10 of Set 13 | muana
# Processing Record 11 of Set 13 | sioux city
# Processing Record 12 of Set 13 | owensboro
# Processing Record 13 of Set 13 | marsabit
# Processing Record 14 of Set 13 | catuday
# Processing Record 15 of Set 13 | tucurui
# Processing Record 16 of Set 13 | tammisaari
# Processing Record 17 of Set 13 | muli
# Processing Record 18 of Set 13 | urdoma
# Processing Record 19 of Set 13 | tlahualilo
# City not found. Skipping...
# Processing Record 20 of Set 13 | mount gambier
# Processing Record 21 of Set 13 | dongkan
# Processing Record 22 of Set 13 | luganville
# Processing Record 23 of Set 13 | pinega
# Processing Record 24 of Set 13 | mae hong son
# Processing Record 25 of Set 13 | staryy nadym
# Processing Record 26 of Set 13 | dukat
# Processing Record 27 of Set 13 | adrar
# Processing Record 28 of Set 13 | hibbing
# Processing Record 29 of Set 13 | ormara
# Processing Record 30 of Set 13 | goderich
# Processing Record 31 of Set 13 | coquimbo
# Processing Record 32 of Set 13 | cartagena del chaira
# Processing Record 33 of Set 13 | stornoway
# Processing Record 34 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 35 of Set 13 | mount darwin
# Processing Record 36 of Set 13 | enid
# Processing Record 37 of Set 13 | teluknaga
# Processing Record 38 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 39 of Set 13 | sisimiut
# Processing Record 40 of Set 13 | lake city
# Processing Record 41 of Set 13 | imeni morozova
# Processing Record 42 of Set 13 | bilasipara
# Processing Record 43 of Set 13 | olinda
# Processing Record 44 of Set 13 | bikin
# Processing Record 45 of Set 13 | buraydah
# Processing Record 46 of Set 13 | farsala
# Processing Record 47 of Set 13 | vostok
# Processing Record 48 of Set 13 | naze
# Processing Record 49 of Set 13 | mildura
# Processing Record 50 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 1 of Set 14 | zdvinsk
# Processing Record 2 of Set 14 | elizabeth city
# Processing Record 3 of Set 14 | worland
# Processing Record 4 of Set 14 | liberty
# Processing Record 5 of Set 14 | half moon bay
# Processing Record 6 of Set 14 | conde
# Processing Record 7 of Set 14 | rantauprapat
# Processing Record 8 of Set 14 | novoagansk
# Processing Record 9 of Set 14 | wadi maliz
# Processing Record 10 of Set 14 | zhezkazgan
# Processing Record 11 of Set 14 | camacha
# Processing Record 12 of Set 14 | jinchengjiang
# City not found. Skipping...
# Processing Record 13 of Set 14 | lata
# Processing Record 14 of Set 14 | enshi
# Processing Record 15 of Set 14 | inongo
# Processing Record 16 of Set 14 | santa cruz cabralia
# Processing Record 17 of Set 14 | shelburne
# Processing Record 18 of Set 14 | pangkalanbuun
# Processing Record 19 of Set 14 | boueni
# Processing Record 20 of Set 14 | kerema
# Processing Record 21 of Set 14 | nishihara
# Processing Record 22 of Set 14 | zhoucheng
# Processing Record 23 of Set 14 | zhicheng
# Processing Record 24 of Set 14 | mogadishu
# Processing Record 25 of Set 14 | san luis rio colorado
# Processing Record 26 of Set 14 | lima
# Processing Record 27 of Set 14 | kisangani
# Processing Record 28 of Set 14 | rundu
# Processing Record 29 of Set 14 | magole
# Processing Record 30 of Set 14 | morondava
# Processing Record 31 of Set 14 | paoua
# Processing Record 32 of Set 14 | whyalla
# Processing Record 33 of Set 14 | winnemucca
# Processing Record 34 of Set 14 | pokhara
# Processing Record 35 of Set 14 | sibu
# Processing Record 36 of Set 14 | salamanca
# Processing Record 37 of Set 14 | dicabisagan
# Processing Record 38 of Set 14 | kisanga
# Processing Record 39 of Set 14 | le port
# Processing Record 40 of Set 14 | anadyr
# Processing Record 41 of Set 14 | olafsvik
# Processing Record 42 of Set 14 | itaberaba
# Processing Record 43 of Set 14 | bestobe
# Processing Record 44 of Set 14 | khani
# Processing Record 45 of Set 14 | nichinan
# Processing Record 46 of Set 14 | bundaberg
# Processing Record 47 of Set 14 | vanimo
# Processing Record 48 of Set 14 | bousse
# Processing Record 49 of Set 14 | balakhta
# Processing Record 50 of Set 14 | bardiyah
# Processing Record 1 of Set 15 | meadow lake
# Processing Record 2 of Set 15 | visby
# Processing Record 3 of Set 15 | prince rupert
# Processing Record 4 of Set 15 | alta floresta
# Processing Record 5 of Set 15 | katha
# City not found. Skipping...
# Processing Record 6 of Set 15 | regeneracao
# Processing Record 7 of Set 15 | iquitos
# Processing Record 8 of Set 15 | vila
# Processing Record 9 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 10 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 11 of Set 15 | toora-khem
# Processing Record 12 of Set 15 | portobelo
# Processing Record 13 of Set 15 | vestmannaeyjar
# Processing Record 14 of Set 15 | kokstad
# Processing Record 15 of Set 15 | faya
# Processing Record 16 of Set 15 | yzeure
# Processing Record 17 of Set 15 | kitui
# Processing Record 18 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 19 of Set 15 | vysokogornyy
# Processing Record 20 of Set 15 | hervey bay
# Processing Record 21 of Set 15 | scarborough
# Processing Record 22 of Set 15 | kavaratti
# Processing Record 23 of Set 15 | agadir
# Processing Record 24 of Set 15 | dunedin
# Processing Record 25 of Set 15 | acapulco
# Processing Record 26 of Set 15 | ajdabiya
# Processing Record 27 of Set 15 | ahipara
# Processing Record 28 of Set 15 | gorontalo
# Processing Record 29 of Set 15 | marawi
# Processing Record 30 of Set 15 | marzuq
# Processing Record 31 of Set 15 | talcahuano
# Processing Record 32 of Set 15 | tarakan
# Processing Record 33 of Set 15 | yirol
# City not found. Skipping...
# Processing Record 34 of Set 15 | las margaritas
# Processing Record 35 of Set 15 | xadani
# City not found. Skipping...
# Processing Record 36 of Set 15 | pacific grove
# Processing Record 37 of Set 15 | impfondo
# Processing Record 38 of Set 15 | santo antonio do sudoeste
# Processing Record 39 of Set 15 | verkhoyansk
# Processing Record 40 of Set 15 | ginda
# Processing Record 41 of Set 15 | bonavista
# Processing Record 42 of Set 15 | bilibino
# Processing Record 43 of Set 15 | cascais
# Processing Record 44 of Set 15 | teguldet
# Processing Record 45 of Set 15 | hambantota
# Processing Record 46 of Set 15 | beringovskiy
# Processing Record 47 of Set 15 | ramos arizpe
# Processing Record 48 of Set 15 | zima
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Grindavik      IS  63.8424  -22.4338     50.47        71          40
# 1         Lompoc      US  34.6391 -120.4579     69.69        61           0
# 2        Amuntai      ID  -2.4177  115.2494     74.41        98         100
# 3     Sao Filipe      CV  14.8961  -24.4956     72.95        70           0
# 4          Gazli      UZ  40.1333   63.4500     76.87        25          45
# 5          Lahij      YE  13.1667   44.5833     79.52        56           0
# 6           Hilo      US  19.7297 -155.0900     82.27        79          40
# 7  Mar Del Plata      AR -38.0023  -57.5575     55.42        76          75
# 8       Hermanus      ZA -34.4187   19.2345     60.80        83         100
# 9         Namibe      AO -15.1961   12.1522     72.61        74          13
#
#    Wind Speed Current Description
# 0       13.80    scattered clouds
# 1       17.00           clear sky
# 2        0.74     overcast clouds
# 3       11.72           clear sky
# 4       14.58    scattered clouds
# 5        7.27           clear sky
# 6        5.99    scattered clouds
# 7       18.99       broken clouds
# 8        8.46     overcast clouds
# 9        6.58          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
